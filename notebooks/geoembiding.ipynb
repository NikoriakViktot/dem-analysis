# %%
import ee, geemap
ee.Authenticate()
ee.Initialize(project='ee-nikoriakviktor')

col = ee.ImageCollection('GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL')
print('Tiles found:', col.size().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=qUXFHCzELNA_5zF-nxdQGBaPJAnYcCdC34sbgO5SJ9g&tc=l0n-qPqQLKOacTMNQCj8JfWzkr74xfLUY8jJKz-5754&cc=JVF2hcdfyGGAjffLpXWUKLmXH_sjGhjjUML3xbj90Dk>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=qUXFHCzELNA_5zF-nxdQGBaPJAnYcCdC34sbgO5SJ9g&tc=l0n-qPqQLKOacTMNQCj8JfWzkr74xfLUY8jJKz-5754&cc=JVF2hcdfyGGAjffLpXWUKLmXH_sjGhjjUML3xbj90Dk</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# gio: https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=qUXFHCzELNA_5zF-nxdQGBaPJAnYcCdC34sbgO5SJ9g&tc=l0n-qPqQLKOacTMNQCj8JfWzkr74xfLUY8jJKz-5754&cc=JVF2hcdfyGGAjffLpXWUKLmXH_sjGhjjUML3xbj90Dk: Operation not supported
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 import ee, geemap
# ----> 2 ee.Authenticate()
#       3 ee.Initialize(project='ee-nikoriakviktor')
#       5 col = ee.ImageCollection('GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL')
#
# File ~/miniforge3/envs/geoid/lib/python3.11/site-packages/ee/__init__.py:159, in Authenticate(authorization_code, quiet, code_verifier, auth_mode, scopes, force)
#     128 def Authenticate(
#     129     authorization_code: Optional[str] = None,
#     130     quiet: Optional[bool] = None,
#    (...)    134     force: bool = False,
#     135 ) -> Optional[bool]:
#     136   """Prompts the user to authorize access to Earth Engine via OAuth2.
#     137
#     138   Args:
#    (...)    157     True if we found valid credentials and didn't run the auth flow.
#     158   """
# --> 159   return oauth.authenticate(authorization_code, quiet, code_verifier, auth_mode,
#     160                             scopes, force)
#
# File ~/miniforge3/envs/geoid/lib/python3.11/site-packages/ee/oauth.py:553, in authenticate(cli_authorization_code, quiet, cli_code_verifier, auth_mode, scopes, force)
#     550 if flow.display_instructions(quiet):
#     551   _open_new_browser(flow.auth_url)
# --> 553 flow.save_code()
#
# File ~/miniforge3/envs/geoid/lib/python3.11/site-packages/ee/oauth.py:603, in Flow.save_code(self, code)
#     601   redirect_uri = self.server.url
#     602   code = self.server.fetch_code()  # Waits for oauth callback
# --> 603 _obtain_and_write_token(code, self.code_verifier, self.scopes, redirect_uri)
#
# File ~/miniforge3/envs/geoid/lib/python3.11/site-packages/ee/oauth.py:270, in _obtain_and_write_token(auth_code, code_verifier, scopes, redirect_uri)
#     267 fetched_info = json.loads(
#     268     urllib.request.urlopen(fetch_client).read().decode())
#     269 if 'error' in fetched_info:
# --> 270   raise ee_exception.EEException(
#     271       'Cannot authenticate: %s' % fetched_info['error']
#     272   )
#     273 client_info = {k: fetched_info[k] for k in ['client_id', 'client_secret']}
#     274 scopes = fetched_info.get('scopes') or scopes
#
# EEException: Cannot authenticate: Invalid request.

# %%
from pathlib import Path
# Папки з різними наборами растрів
attr_folder = Path("/mnt/c/Users/5302/OneDrive/PhD/paper_DEM_artickle/data/DATA_UTM/dem/terrain_attributes")
geomorphon_folder = Path("/mnt/c/Users/5302/OneDrive/PhD/paper_DEM_artickle/data/DATA_UTM/dem/geomorphons")
hand_folder = Path("/mnt/c/Users/5302/OneDrive/PhD/paper_DEM_artickle/data/DATA_UTM/dem/hand_outputs")
distance_folder = Path("/mnt/c/Users/5302/OneDrive/PhD/paper_DEM_artickle/data/DATA_UTM/dem/distance_to_stream")
twi_folder = Path("/mnt/c/Users/5302/OneDrive/PhD/paper_DEM_artickle/data/DATA_UTM/dem/flow_TWI")

# %%
# Формуємо списки шляхів
attr_paths = sorted(attr_folder.glob("*.tif"))
geomorphon_paths = sorted(geomorphon_folder.glob("*_geomorphons.tif"))
hand_paths = sorted(hand_folder.glob("*_hand_2000.tif"))
dist_paths = sorted(distance_folder.glob("*_distance_to_stream.tif"))
twi_paths = sorted(twi_folder.glob("*_twi.tif"))
# Словник назв форм

# %%
landform_names = {
    1: "Flat", 2: "Peak", 3: "Ridge", 4: "Shoulder", 5: "Spur",
    6: "Slope", 7: "Hollow", 8: "Footslope", 9: "Valley", 10: "Pit"
}

# 🔍 Атрибути, які нас цікавлять
important_attributes = {"slope", "curvature", "tpi", "tri", "roughness", "aspect"}

# 📦 Вибір файлів, які містять лише ці атрибути
filtered_attr_paths = [p for p in attr_paths if any(attr in p.stem for attr in important_attributes)]
# 🔁 Об'єднаний цикл по всіх растрах (атрибути, геоморфони, HAND, distance)
for path in filtered_attr_paths + geomorphon_paths + hand_paths + dist_paths + twi_paths:
    filename = path.stem
    print(filename)

    if "geomorphons" in filename:
        # Geomorphons
        dem_name = "_".join(filename.split("_")[:2])
        print(dem_name, path.name)
        col_class = f"{dem_name}_geomorphon"
        col_name = f"{dem_name}_landform"
# Out:
# alos_dem_utm32635_aspect
# alos_dem_utm32635_curvature
# alos_dem_utm32635_roughness
# alos_dem_utm32635_slope
# alos_dem_utm32635_tpi
# alos_dem_utm32635_tri
# aster_dem_utm32635_aspect
# aster_dem_utm32635_curvature
# aster_dem_utm32635_roughness
# aster_dem_utm32635_slope
# aster_dem_utm32635_tpi
# aster_dem_utm32635_tri
# copernicus_dеm_utm32635_aspect
# copernicus_dеm_utm32635_curvature
# copernicus_dеm_utm32635_roughness
# copernicus_dеm_utm32635_slope
# copernicus_dеm_utm32635_tpi
# copernicus_dеm_utm32635_tri
# fab_dem_utm32635_aspect
# fab_dem_utm32635_curvature
# fab_dem_utm32635_roughness
# fab_dem_utm32635_slope
# fab_dem_utm32635_tpi
# fab_dem_utm32635_tri
# nasa_dem_utm32635_aspect
# nasa_dem_utm32635_curvature
# nasa_dem_utm32635_roughness
# nasa_dem_utm32635_slope
# nasa_dem_utm32635_tpi
# nasa_dem_utm32635_tri
# srtm_dem_utm32635_aspect
# srtm_dem_utm32635_curvature
# srtm_dem_utm32635_roughness
# srtm_dem_utm32635_slope
# srtm_dem_utm32635_tpi
# srtm_dem_utm32635_tri
# tan_dem_utm32635_aspect
# tan_dem_utm32635_curvature
# tan_dem_utm32635_roughness
# tan_dem_utm32635_slope
# tan_dem_utm32635_tpi
# tan_dem_utm32635_tri
# alos_dem_utm32635_geomorphons
# alos_dem
# aster_dem_utm32635_geomorphons
# aster_dem
# copernicus_dеm_utm32635_geomorphons
# copernicus_dеm
# fab_dem_utm32635_geomorphons
# fab_dem
# nasa_dem_utm32635_geomorphons
# nasa_dem
# srtm_dem_utm32635_geomorphons
# srtm_dem
# tan_dem_utm32635_geomorphons
# tan_dem
# alos_dem_utm32635_hand_2000
# aster_dem_utm32635_hand_2000
# copernicus_dеm_utm32635_hand_2000
# fab_dem_utm32635_hand_2000
# nasa_dem_utm32635_hand_2000
# srtm_dem_utm32635_hand_2000
# tan_dem_utm32635_hand_2000
# alos_dem_utm32635_distance_to_stream
# aster_dem_utm32635_distance_to_stream
# copernicus_dеm_utm32635_distance_to_stream
# fab_dem_utm32635_distance_to_stream
# nasa_dem_utm32635_distance_to_stream
# srtm_dem_utm32635_distance_to_stream
# tan_dem_utm32635_distance_to_stream
# alos_dem_utm32635_twi
# aster_dem_utm32635_twi
# copernicus_dеm_utm32635_twi
# fab_dem_utm32635_twi
# nasa_dem_utm32635_twi
# srtm_dem_utm32635_twi
# tan_dem_utm32635_twi
